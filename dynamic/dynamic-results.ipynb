# %%
import nbformat as nbf
import pandas as pd
import re

# %%
dfs = list()
def get_params(nb):
    d=nbf.read(nb, nbf.NO_CONVERT)
    for c in d.cells:
        if "### Parameters" in c.source:
            vocabulary_size = re.search("vocabulary_size = (\d+)", c.source).groups()[0]
            num_patterns = re.search("num_patterns = (\d+)", c.source).groups()[0]
            num_new_patterns = re.search("num_new_patterns = (\d+)", c.source).groups()[0]
            return int(vocabulary_size), int(num_patterns), int(num_new_patterns)
            
def get_result_from_nb(nb):
    try:
        global dfs
        d=nbf.read(nb, nbf.NO_CONVERT)
        cur_df = pd.read_html(d.cells[-1].outputs[-1]["data"]["text/html"])[0]
        cur_df["file"] = nb

        vocabulary_size, num_patterns, num_new_patterns = get_params(nb)
        cur_df["vocabulary_size"] = vocabulary_size
        cur_df["num_patterns"] = num_patterns
        cur_df["num_new_patterns"] = num_new_patterns
        dfs.append(cur_df)
    except:
        pass

# %%
nbs = ["dynamic-2.ipynb", "dynamic-3.ipynb", "dynamic-4.ipynb", "dynamic-5.ipynb", "dynamic-6.ipynb"]
for nb in nbs:
    get_result_from_nb(nb)
df = pd.concat(dfs)
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#     g      prec       rec       acc        f1   TP   TN  FP   FN  \
# 0   9  1.000000  0.193237  0.761429  0.323887   40  493   0  167
# 0  10  1.000000  0.735294  0.922857  0.847458  150  496   0   54
# 0  14  1.000000  0.483146  0.868571  0.651515   86  522   0   92
# 0  19  0.956522  0.112821  0.751429  0.201835   22  504   1  173
# 0  35  1.000000  0.218750  0.785714  0.358974   42  508   0  150
#
#    num_feedbacks_new  num_feedbacks_old  num_feedbacks             file  \
# 0                 19                  2             21  dynamic-2.ipynb
# 0                108                 27            135  dynamic-3.ipynb
# 0                 52                  4             56  dynamic-4.ipynb
# 0                 36                  2             38  dynamic-5.ipynb
# 0                 17                  2             19  dynamic-6.ipynb
#
#    vocabulary_size  num_patterns  num_new_patterns
# 0               10            20                 3
# 0               20            10                 3
# 0               20            20                 5
# 0               20            40                 5
# 0               40            80                 5
